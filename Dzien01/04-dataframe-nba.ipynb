# %%
import pandas as pd

# %%
df = pd.read_csv("http://51.91.120.89/extras/nba.csv", index_col="Name")
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
df.isna().sum()
# Out:
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
# usuwanie wierszy z NaN (wszedzie)
df.dropna(axis=0, how='all', inplace=True )

# %%
df.isna().sum()
# Out:
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
# zamien w College NaN na string pusty
df.College = df.College.replace(pd.np.NaN, "")
# Out:
# C:\Users\kurs\AppData\Local\Temp\ipykernel_3384\3606624673.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df.College = df.College.replace(pd.np.NaN, "")

# %%
df.Weight /= 2.2

# %%
def convert_height(s):
    feet, inches = s.split("-")
    return int(feet)*30.4 + int(inches)*2.54

convert_height("6-2")
# Out:
# 187.48

# %%
df.Height = df.Height.apply(convert_height)

# %%
df
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# John Holland   Boston Celtics    30.0       SG  27.0  195.10   93.181818
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
# ...                       ...     ...      ...   ...     ...         ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0  207.80  106.363636
# Shelvin Mack        Utah Jazz     8.0       PG  26.0  190.02   92.272727
# Raul Neto           Utah Jazz    25.0       PG  24.0  184.94   81.363636
# Tibor Pleiss        Utah Jazz    21.0        C  26.0  220.42  116.363636
# Jeff Withey         Utah Jazz    24.0        C  26.0  212.80  105.000000
#
#                          College     Salary
# Name
# ...

# %%
df.to_csv("nba-ok.csv", index_label="nba_index")

# %%
df.sort_values(["Salary","Age","Height"], ascending=[True, False, True])
# Out:
#                                           Team  Number Position   Age  Height  \
# Name
# Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0  200.18
# Orlando Johnson           New Orleans Pelicans     0.0       SG  27.0  195.10
# Phil Pressey                      Phoenix Suns    25.0       PG  25.0  179.94
# Alan Williams                     Phoenix Suns    15.0        C  23.0  202.72
# Jordan McRae               Cleveland Cavaliers    12.0       SG  25.0  195.10
# ...                                        ...     ...      ...   ...     ...
# Greg Smith              Minnesota Timberwolves     4.0       PF  25.0  207.80
# Ray McCallum                 Memphis Grizzlies     5.0       PG  24.0  190.02
# Xavier Munford               Memphis Grizzlies    14.0       PG  24.0  190.02
# Briante Weber                       Miami Heat    12.0       PG  23.0  187.48
# Axel Toupane                    Denver Nuggets     6.0       SG  23.0  200.18
#
# ...

# %%
df.nlargest(10, "Weight")
# Out:
#                                      Team  Number Position   Age  Height  \
# Name
# Nikola Pekovic     Minnesota Timberwolves    14.0        C  30.0  210.34
# Boban Marjanovic        San Antonio Spurs    40.0        C  27.0  220.42
# Al Jefferson            Charlotte Hornets    25.0        C  31.0  207.80
# Jusuf Nurkic               Denver Nuggets    23.0        C  21.0  212.80
# Andre Drummond            Detroit Pistons     0.0        C  22.0  210.34
# Kevin Seraphin            New York Knicks     1.0        C  26.0  207.80
# Brook Lopez                 Brooklyn Nets    11.0        C  28.0  212.80
# Jahlil Okafor          Philadelphia 76ers     8.0        C  20.0  210.34
# Cristiano Felicio           Chicago Bulls     6.0       PF  23.0  207.80
# Timofey Mozgov        Cleveland Cavaliers    20.0        C  29.0  215.34
#
#                        Weight      College      Salary
# Name
# Nikola Pekovic     139.545455               12100000.0
# ...

# %%
df.nsmallest(10, "Weight")
# Out:
#                                     Team  Number Position   Age  Height  \
# Name
# Aaron Brooks               Chicago Bulls     0.0       PG  31.0  182.40
# Bryce Cotton           Memphis Grizzlies     8.0       PG  23.0  184.94
# Briante Weber                 Miami Heat    12.0       PG  23.0  187.48
# Brandon Jennings           Orlando Magic    55.0       PG  26.0  184.94
# Tim Frazier         New Orleans Pelicans     2.0       PG  25.0  184.94
# Steve Blake              Detroit Pistons    22.0       PG  36.0  190.02
# Dennis Schroder            Atlanta Hawks    17.0       PG  22.0  184.94
# Brian Roberts     Portland Trail Blazers     2.0       PG  30.0  184.94
# Shane Larkin               Brooklyn Nets     0.0       PG  23.0  179.94
# Ish Smith             Philadelphia 76ers     1.0       PG  27.0  182.40
#
#                      Weight                College     Salary
# Name
# Aaron Brooks      73.181818                 Oregon  2250000.0
# ...

# %%
# %%timeit -r 10 -n 1000
# filtrowanie
# wzrost > 200cm i zarobki >1mln i wiek <25
df[ (df.Height>200)&(df.Salary>1_000_000)&(df.Age<25) ]
# Out:
# 529 µs ± 37.7 µs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %%
# %%timeit -r 10 -n 1000
df.query(" Height>200 and Salary>1E6 and Age<25")
# Out:
# 1.59 ms ± 33.6 µs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %%
df.columns = ['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary in USD']
df.head()
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# John Holland   Boston Celtics    30.0       SG  27.0  195.10   93.181818
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
#
#                          College  Salary in USD
# Name
# Avery Bradley              Texas      7730337.0
# Jae Crowder            Marquette      6796117.0
# John Holland   Boston University            NaN
# R.J. Hunter        Georgia State      1148640.0
# Jonas Jerebko                         5000000.0

# %%
df[ df['Salary in USD']>1E6 ]
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
# Amir Johnson   Boston Celtics    90.0       PF  29.0  205.26  109.090909
# ...                       ...     ...      ...   ...     ...         ...
# Rodney Hood         Utah Jazz     5.0       SG  23.0  202.72   93.636364
# Joe Ingles          Utah Jazz     2.0       SF  28.0  202.72  102.727273
# Trey Lyles          Utah Jazz    41.0       PF  20.0  207.80  106.363636
# Shelvin Mack        Utah Jazz     8.0       PG  26.0  190.02   92.272727
# Tibor Pleiss        Utah Jazz    21.0        C  26.0  220.42  116.363636
#
#                      College  Salary in USD
# Name
# ...

# %%
df.query(" `Salary in USD`>1E6 ")
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
# Amir Johnson   Boston Celtics    90.0       PF  29.0  205.26  109.090909
# ...                       ...     ...      ...   ...     ...         ...
# Rodney Hood         Utah Jazz     5.0       SG  23.0  202.72   93.636364
# Joe Ingles          Utah Jazz     2.0       SF  28.0  202.72  102.727273
# Trey Lyles          Utah Jazz    41.0       PF  20.0  207.80  106.363636
# Shelvin Mack        Utah Jazz     8.0       PG  26.0  190.02   92.272727
# Tibor Pleiss        Utah Jazz    21.0        C  26.0  220.42  116.363636
#
#                      College  Salary in USD
# Name
# ...

# %%
df[ ["Team","Position"] ]
# Out:
#                          Team Position
# Name
# Avery Bradley  Boston Celtics       PG
# Jae Crowder    Boston Celtics       SF
# John Holland   Boston Celtics       SG
# R.J. Hunter    Boston Celtics       SG
# Jonas Jerebko  Boston Celtics       PF
# ...                       ...      ...
# Trey Lyles          Utah Jazz       PF
# Shelvin Mack        Utah Jazz       PG
# Raul Neto           Utah Jazz       PG
# Tibor Pleiss        Utah Jazz        C
# Jeff Withey         Utah Jazz        C
#
# [457 rows x 2 columns]

# %%
df
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# John Holland   Boston Celtics    30.0       SG  27.0  195.10   93.181818
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
# ...                       ...     ...      ...   ...     ...         ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0  207.80  106.363636
# Shelvin Mack        Utah Jazz     8.0       PG  26.0  190.02   92.272727
# Raul Neto           Utah Jazz    25.0       PG  24.0  184.94   81.363636
# Tibor Pleiss        Utah Jazz    21.0        C  26.0  220.42  116.363636
# Jeff Withey         Utah Jazz    24.0        C  26.0  212.80  105.000000
#
#                          College  Salary in USD
# Name
# ...

# %%
df.loc[ ["Jae Crowder","R.J. Hunter"] ]
# Out:
#                        Team  Number Position   Age  Height      Weight  \
# Name
# Jae Crowder  Boston Celtics    99.0       SF  25.0  197.64  106.818182
# R.J. Hunter  Boston Celtics    28.0       SG  22.0  195.10   84.090909
#
#                    College  Salary in USD
# Name
# Jae Crowder      Marquette      6796117.0
# R.J. Hunter  Georgia State      1148640.0

# %%
df.loc["Jae Crowder":"Raul Neto":3 , "Number":"Weight"]
# Out:
#                  Number Position   Age  Height      Weight
# Name
# Jae Crowder        99.0       SF  25.0  197.64  106.818182
# Jonas Jerebko       8.0       PF  29.0  207.80  105.000000
# Kelly Olynyk       41.0        C  25.0  212.80  108.181818
# Jared Sullinger     7.0        C  24.0  205.26  118.181818
# James Young        13.0       SG  20.0  197.64   97.727273
# ...                 ...      ...   ...     ...         ...
# Trevor Booker      33.0       PF  28.0  202.72  103.636364
# Dante Exum         11.0       PG  20.0  197.64   86.363636
# Gordon Hayward     20.0       SF  26.0  202.72  102.727273
# Chris Johnson      23.0       SF  26.0  197.64   93.636364
# Raul Neto          25.0       PG  24.0  184.94   81.363636
#
# [152 rows x 5 columns]

# %%
df.loc[ : , "Number":"Weight"]
# Out:
#                Number Position   Age  Height      Weight
# Name
# Avery Bradley     0.0       PG  25.0  187.48   81.818182
# Jae Crowder      99.0       SF  25.0  197.64  106.818182
# John Holland     30.0       SG  27.0  195.10   93.181818
# R.J. Hunter      28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko     8.0       PF  29.0  207.80  105.000000
# ...               ...      ...   ...     ...         ...
# Trey Lyles       41.0       PF  20.0  207.80  106.363636
# Shelvin Mack      8.0       PG  26.0  190.02   92.272727
# Raul Neto        25.0       PG  24.0  184.94   81.363636
# Tibor Pleiss     21.0        C  26.0  220.42  116.363636
# Jeff Withey      24.0        C  26.0  212.80  105.000000
#
# [457 rows x 5 columns]

# %%
df
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# John Holland   Boston Celtics    30.0       SG  27.0  195.10   93.181818
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
# ...                       ...     ...      ...   ...     ...         ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0  207.80  106.363636
# Shelvin Mack        Utah Jazz     8.0       PG  26.0  190.02   92.272727
# Raul Neto           Utah Jazz    25.0       PG  24.0  184.94   81.363636
# Tibor Pleiss        Utah Jazz    21.0        C  26.0  220.42  116.363636
# Jeff Withey         Utah Jazz    24.0        C  26.0  212.80  105.000000
#
#                          College  Salary in USD
# Name
# ...

# %%
df.iloc[ 1:5 , [0,-1] ]
# Out:
#                          Team  Salary in USD
# Name
# Jae Crowder    Boston Celtics      6796117.0
# John Holland   Boston Celtics            NaN
# R.J. Hunter    Boston Celtics      1148640.0
# Jonas Jerebko  Boston Celtics      5000000.0

# %%
df.iloc[ : , [0,-1] ]
# Out:
#                          Team  Salary in USD
# Name
# Avery Bradley  Boston Celtics      7730337.0
# Jae Crowder    Boston Celtics      6796117.0
# John Holland   Boston Celtics            NaN
# R.J. Hunter    Boston Celtics      1148640.0
# Jonas Jerebko  Boston Celtics      5000000.0
# ...                       ...            ...
# Trey Lyles          Utah Jazz      2239800.0
# Shelvin Mack        Utah Jazz      2433333.0
# Raul Neto           Utah Jazz       900000.0
# Tibor Pleiss        Utah Jazz      2900000.0
# Jeff Withey         Utah Jazz       947276.0
#
# [457 rows x 2 columns]

# %%
df.iloc[ : , -2: ]
# Out:
#                          College  Salary in USD
# Name
# Avery Bradley              Texas      7730337.0
# Jae Crowder            Marquette      6796117.0
# John Holland   Boston University            NaN
# R.J. Hunter        Georgia State      1148640.0
# Jonas Jerebko                         5000000.0
# ...                          ...            ...
# Trey Lyles              Kentucky      2239800.0
# Shelvin Mack              Butler      2433333.0
# Raul Neto                              900000.0
# Tibor Pleiss                          2900000.0
# Jeff Withey               Kansas       947276.0
#
# [457 rows x 2 columns]
