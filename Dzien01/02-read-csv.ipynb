# %%
import pandas as pd
import numpy as np

# %%
# ładowanie danych do DF z pliku CSV
df = pd.read_csv("http://51.91.120.89/extras/f500.csv")
df
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
df.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
df = pd.read_csv("http://51.91.120.89/extras/f500nh.csv", header=None, names=['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
       'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
       'country', 'hq_location', 'website', 'years_on_global_500_list',
       'employees', 'total_stockholder_equity'])
df
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
df.head(3)
# Out:
#          company  rank  revenues  revenue_change  profits  assets  \
# 0        Walmart     1    485873             0.8  13643.0  198825
# 1     State Grid     2    315199            -4.4   9571.3  489838
# 2  Sinopec Group     3    267518            -9.1   1257.9  310726
#
#    profit_change                  ceo               industry     sector  \
# 0           -7.2  C. Douglas McMillon  General Merchandisers  Retailing
# 1           -6.2              Kou Wei              Utilities     Energy
# 2          -65.0            Wang Yupu     Petroleum Refining     Energy
#
#    previous_rank country      hq_location                 website  \
# 0              1     USA  Bentonville, AR  http://www.walmart.com
# 1              2   China   Beijing, China  http://www.sgcc.com.cn
# 2              4   China   Beijing, China  http://www.sinopec.com
#
#    years_on_global_500_list  employees  total_stockholder_equity
# 0                        23    2300000                     77798
# ...

# %%
df.tail(4)
# Out:
#                        company  rank  revenues  revenue_change  profits  \
# 496   New China Life Insurance   497     21796           -13.3    743.9
# 497  Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                        TUI   499     21655            -5.5   1151.7
# 499                 AutoNation   500     21609             3.6    430.5
#
#      assets  profit_change                 ceo  \
# 496  100609          -45.6            Wan Feng
# 497   11630           20.4      David T. Potts
# 498   16247          195.5   Friedrich Joussen
# 499   10060           -2.7  Michael J. Jackson
#
#                             industry              sector  previous_rank  \
# 496  Insurance: Life, Health (stock)          Financials            427
# 497             Food and Drug Stores  Food & Drug Stores            437
# 498                  Travel Services   Business Services            467
# 499              Specialty Retailers           Retailing              0
#
# ...

# %%
df.sample(frac=.01, random_state=0)
# Out:
#                    company  rank  revenues  revenue_change  profits   assets  \
# 90                  Uniper    91     74407             NaN  -3557.5    51541
# 254                  Merck   255     39807             0.8   3920.0    95377
# 283               Barclays   284     36789           -25.7   2807.4  1498612
# 445                 Danone   446     24267            -2.4   1902.1    46350
# 461  Alibaba Group Holding   462     23517            47.9   6489.5    73538
#
#      profit_change                 ceo                         industry  \
# 90             NaN       Klaus Schafer                           Energy
# 254          -11.8  Kenneth C. Frazier                  Pharmaceuticals
# 283            NaN     James E. Staley    Banks: Commercial and Savings
# 445           33.8      Emmanuel Faber           Food Consumer Products
# 461          -42.2        Daniel Zhang  Internet Services and Retailing
#
# ...

# %%
df["rank"].min(), df["rank"].max(), df["rank"].median(), df["rank"].mean(), df["rank"].std()
# Out:
# (1, 500, 250.5, 250.5, 144.4818327679989)

# %%
df.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  500.000000     500.000000      498.000000    499.000000  5.000000e+02
# mean   250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std    144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min      1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%    250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%    375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max    500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list     employees  \
# count     436.000000     500.000000                500.000000  5.000000e+02
# mean       24.152752     222.134000                 15.036000  1.339983e+05
# ...

# %%
# wymuszanie typu ładowanych danych
df = pd.read_csv("http://51.91.120.89/extras/f500.csv", dtype={
    "rank" : "uint16",
    "revenue_change" : "float32"
})
df.dtypes
# Out:
# company                      object
# rank                         uint16
# revenues                      int64
# revenue_change              float32
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
df = pd.read_csv("http://51.91.120.89/extras/f500.csv", dtype={
    "rank" : np.uint16,
    "revenue_change" : np.float32
})
df.dtypes
# Out:
# company                      object
# rank                         uint16
# revenues                      int64
# revenue_change              float32
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
df.revenues = df.revenues.astype("int32")
df.dtypes
# Out:
# company                      object
# rank                         uint16
# revenues                      int32
# revenue_change              float32
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
df.profits.astype('int32', errors='ignore')
# Out:
# 0      13643.0
# 1       9571.3
# 2       1257.9
# 3       1867.5
# 4      16899.3
#         ...
# 495      329.0
# 496      743.9
# 497      406.4
# 498     1151.7
# 499      430.5
# Name: profits, Length: 500, dtype: float64

# %%
(df["rank"] / 2).astype('int32')
# Out:
# 0        0
# 1        1
# 2        1
# 3        2
# 4        2
#       ...
# 495    248
# 496    248
# 497    249
# 498    249
# 499    250
# Name: rank, Length: 500, dtype: int32

# %%
(df["rank"] / 2)
# Out:
# 0        0.5
# 1        1.0
# 2        1.5
# 3        2.0
# 4        2.5
#        ...
# 495    248.0
# 496    248.5
# 497    249.0
# 498    249.5
# 499    250.0
# Name: rank, Length: 500, dtype: float64

# %%
df = pd.read_csv("http://51.91.120.89/extras/f500.csv", usecols=[0,1,7]) # 0 1 7
df
# Out:
#                             company  rank                  ceo
# 0                           Walmart     1  C. Douglas McMillon
# 1                        State Grid     2              Kou Wei
# 2                     Sinopec Group     3            Wang Yupu
# 3          China National Petroleum     4        Zhang Jianhua
# 4                      Toyota Motor     5          Akio Toyoda
# ..                              ...   ...                  ...
# 495  Teva Pharmaceutical Industries   496    Yitzhak Peterburg
# 496        New China Life Insurance   497             Wan Feng
# 497       Wm. Morrison Supermarkets   498       David T. Potts
# 498                             TUI   499    Friedrich Joussen
# 499                      AutoNation   500   Michael J. Jackson
#
# [500 rows x 3 columns]

# %%
df = pd.read_csv("http://51.91.120.89/extras/f500.csv",  skiprows=[1,2], nrows=50, usecols=lambda c:c.startswith( ('p','c') ) ) 
df
# Out:
#                                   company  profits  profit_change  \
# 0                           Sinopec Group   1257.9          -65.0
# 1                China National Petroleum   1867.5          -73.7
# 2                            Toyota Motor  16899.3          -12.3
# 3                              Volkswagen   5937.3            NaN
# 4                       Royal Dutch Shell   4575.0          135.9
# 5                      Berkshire Hathaway  24074.0            NaN
# 6                                   Apple  45687.0          -14.4
# 7                             Exxon Mobil   7840.0          -51.5
# 8                                McKesson   5070.0          124.5
# 9                                      BP    115.0            NaN
# 10                     UnitedHealth Group   7017.0           20.7
# 11                             CVS Health   5317.0            1.5
# 12                    Samsung Electronics  19316.5           16.8
# ...

# %%
df = pd.read_csv("http://51.91.120.89/extras/f500.csv", index_col="company") 
df
# Out:
#                                 rank  revenues  revenue_change  profits  \
# company
# Walmart                            1    485873             0.8  13643.0
# State Grid                         2    315199            -4.4   9571.3
# Sinopec Group                      3    267518            -9.1   1257.9
# China National Petroleum           4    262573           -12.3   1867.5
# Toyota Motor                       5    254694             7.7  16899.3
# ...                              ...       ...             ...      ...
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
# AutoNation                       500     21609             3.6    430.5
#
#                                 assets  profit_change                  ceo  \
# company
# ...

# %%
df.index
# Out:
# Index(['Walmart', 'State Grid', 'Sinopec Group', 'China National Petroleum',
#        'Toyota Motor', 'Volkswagen', 'Royal Dutch Shell', 'Berkshire Hathaway',
#        'Apple', 'Exxon Mobil',
#        ...
#        'National Grid', 'Dollar General', 'Telecom Italia',
#        'Xiamen ITG Holding Group', 'Xinjiang Guanghui Industry Investment',
#        'Teva Pharmaceutical Industries', 'New China Life Insurance',
#        'Wm. Morrison Supermarkets', 'TUI', 'AutoNation'],
#       dtype='object', name='company', length=500)

# %%
# resetowanie indeksu
df.reset_index(inplace=True)
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
df.set_index("company", inplace=True)
df.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# ...

# %%
# ładowanie XLSX
df = pd.read_excel("http://51.91.120.89/extras/films.xlsx", sheet_name=1)
df
# Out:
#     Entry                                Film  \
# 0       1                           Chinatown
# 1       2                       Touch of Evil
# 2       3                             Vertigo
# 3       4                            Badlands
# 4       5                            Rashomon
# 5       6                    Double Indemnity
# 6       7                          Get Carter
# 7       8                        Pulp Fiction
# 8       9                              Hidden
# 9      10                          Goodfellas
# 10     11                    The Conversation
# 11     12                      Bonnie & Clyde
# 12     13                         The Killing
# 13     14                   French Connection
# 14     15                       The Big Sleep
# 15     16                        La Ceremonie
# 16     17                         Point Blank
# 17     18                         Hard Boiled
# 18     19                    Long Good Friday
# ...

# %%
df = pd.read_excel("http://51.91.120.89/extras/films.xlsx", sheet_name=None)
type(df)
# Out:
# dict

# %%
df.keys()
# Out:
# dict_keys(['ROMANCE', 'CRIME', 'COMEDY', 'ACTION', 'ARTHOUSE AND DRAMA', 'SCI-FI AND FANTASY', 'HORROR'])

# %%
#df["ACTION"]
df.get("ACTION")
# Out:
#     Entry                           Film                          Director  \
# 0       1                 Apocalypse Now                   Francis Coppola
# 1       2             North by Northwest                  Alfred Hitchcock
# 2       3   Once Upon a Time in the West                      Sergio Leone
# 3       4                 The Wild Bunch                      Sam Pekinpah
# 4       5                    Deliverance                     John Boorman
# 5       6                    City of God                Fernando Meirelles
# 6       7                 Paths of Glory                   Stanley Kubrick
# 7       7              The Wages of Fear             Henri-Georges Clouzot
# 8       9  Crouching Tiger Hidden Dragon                           Ang Lee
# 9      10              The Thin Red Line                    Terrence Malik
# 10     11        Raiders of the Lost Ark                  Steven Spielberg
# ...
