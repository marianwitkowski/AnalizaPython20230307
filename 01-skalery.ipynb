# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
np.random.seed(1)

df = pd.DataFrame({
    "x1" : np.random.normal(0, 2, 10_000),
    "x2" : np.random.normal(5, 3, 10_000),
    "x3" : np.random.normal(-5, 5, 10_000)
})

# %%
scaler = StandardScaler()
scaler.fit_transform(df[["x1"]])
# Out:
# array([[ 1.61653543],
#        [-0.62228462],
#        [-0.53859835],
#        ...,
#        [-1.02516118],
#        [-0.07255698],
#        [-1.44940235]])

# %%
df1 = pd.DataFrame( StandardScaler().fit_transform(df), columns=['x1','x2','x3'] )
df1
# Out:
#             x1        x2        x3
# 0     1.616535 -0.131753 -1.924757
# 1    -0.622285  0.218475 -0.146416
# 2    -0.538598 -0.361311 -0.820942
# 3    -1.084057 -0.838991 -0.192287
# 4     0.856675 -0.270204  1.045092
# ...        ...       ...       ...
# 9995  0.063263 -0.951512  0.707293
# 9996  0.479912  0.771862  0.569731
# 9997 -1.025161  2.396149 -0.069516
# 9998 -0.072557  0.872313 -1.274092
# 9999 -1.449402 -0.108902  0.358368
#
# [10000 rows x 3 columns]

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(8,6))

ax1.set_title('Przed')
sns.kdeplot(df.x1, ax=ax1)
sns.kdeplot(df.x2, ax=ax1)
sns.kdeplot(df.x3, ax=ax1)

ax2.set_title('Po')
sns.kdeplot(df1.x1, ax=ax2)
sns.kdeplot(df1.x2, ax=ax2)
sns.kdeplot(df1.x3, ax=ax2)
plt.show()

# %%
np.random.seed(1)

df = pd.DataFrame({
    "x1" : np.random.chisquare(8, 10_000),
    "x2" : np.random.beta(8, 2, 10_000)*40,
    "x3" : np.random.normal(50, 3, 10_000)
})

# %%
df1 = pd.DataFrame( MinMaxScaler().fit_transform(df), columns=['x1','x2','x3'] )

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(8,6))

ax1.set_title('Przed')
sns.kdeplot(df.x1, ax=ax1)
sns.kdeplot(df.x2, ax=ax1)
sns.kdeplot(df.x3, ax=ax1)

ax2.set_title('Po')
sns.kdeplot(df1.x1, ax=ax2)
sns.kdeplot(df1.x2, ax=ax2)
sns.kdeplot(df1.x3, ax=ax2)
plt.show()

# %%
np.random.seed(1)

df = pd.DataFrame({
    "x1" : np.concatenate([ np.random.normal(20,1,1000), np.random.normal(1,1,50) ]),
    "x2" : np.concatenate([ np.random.normal(30,1,1000), np.random.normal(50,1,50) ])
})

# %%
df1 = pd.DataFrame( RobustScaler().fit_transform(df), columns=['x1','x2'] )

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(8,6))

ax1.set_title('Przed')
sns.kdeplot(df.x1, ax=ax1)
sns.kdeplot(df.x2, ax=ax1)

ax2.set_title('Po')
sns.kdeplot(df1.x1, ax=ax2)
sns.kdeplot(df1.x2, ax=ax2)
plt.show()

# %%
df1 = pd.DataFrame( StandardScaler().fit_transform(df), columns=['x1','x2'] )

fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(8,6))

ax1.set_title('Przed')
sns.kdeplot(df.x1, ax=ax1)
sns.kdeplot(df.x2, ax=ax1)

ax2.set_title('Po')
sns.kdeplot(df1.x1, ax=ax2)
sns.kdeplot(df1.x2, ax=ax2)
plt.show()
